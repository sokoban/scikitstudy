# %% [markdown]
# 머신러닝은 반드시 트레이닝 셋과 테스트 셋으로 나누어서 한다.
#
#
# Training data set : 교과서 , 학습에만 이용함
#
# test data set :실전 문제,
#
# - 트레이닝 셋을 이용 모델을 학습 시킴
# - Validation(모의고사) 을 이용하여 학습을 시킴
# - Test 데이터를 이용하여 이를 검증함
#
# Training, Testing
# Training, Validation, Testing
#
# Online Learning
# 트레이닝셋이 100만개

# %%
import tensorflow as tf
import numpy as np
tf.set_random_seed(777)  # for reproducibility


xy = np.array([[828.659973, 833.450012, 908100, 828.349976, 831.659973],
               [823.02002, 828.070007, 1828100, 821.655029, 828.070007],
               [819.929993, 824.400024, 1438100, 818.97998, 824.159973],
               [816, 820.958984, 1008100, 815.48999, 819.23999],
               [819.359985, 823, 1188100, 818.469971, 818.97998],
               [819, 823, 1198100, 816, 820.450012],
               [811.700012, 815.25, 1098100, 809.780029, 813.669983],
               [809.51001, 816.659973, 1398100, 804.539978, 809.559998]])

x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]

# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([4, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(101):
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)
# Out:
# (0, 'Cost: ', 1.2088272e+11, '\nPrediction:\n', array([[ 246290.984375],
#        [ 494301.59375 ],
#        [ 389156.40625 ],
#        [ 273227.25    ],
#        [ 321757.5     ],
#        [ 324450.75    ],
#        [ 297479.625   ],
#        [ 378352.40625 ]], dtype=float32))
# (1, 'Cost: ', 1.3281148e+26, '\nPrediction:\n', array([[ -8.12922438e+12],
#        [ -1.63649621e+13],
#        [ -1.28737251e+13],
#        [ -9.02441311e+12],
#        [ -1.06357525e+13],
#        [ -1.07252715e+13],
#        [ -9.83008333e+12],
#        [ -1.25156500e+13]], dtype=float32))
# (2, 'Cost: ', inf, '\nPrediction:\n', array([[  2.69454113e+20],
#        [  5.42438766e+20],
#        [  4.26717015e+20],
#        [  2.99126343e+20],
#        [  3.52536396e+20],
#        [  3.55503634e+20],
#        [  3.25831387e+20],
#        [  4.14848095e+20]], dtype=float32))
# (3, 'Cost: ', inf, '\nPrediction:\n', array([[ -8.93141940e+27],
#        [ -1.79798626e+28],
#        [ -1.41441098e+28],
#        [ -9.91494490e+27],
#        [ -1.16852940e+28],
#        [ -1.17836455e+28],
#        [ -1.08001183e+28],
#        [ -1.37506977e+28]], dtype=float32))
# (4, 'Cost: ', inf, '\nPrediction:\n', array([[  2.96043932e+35],
#        [  5.95966796e+35],
#        [  4.68825561e+35],
#        [  3.28644241e+35],
#        [  3.87324778e+35],
#        [  3.90584819e+35],
#        [  3.57984530e+35],
#        [  4.55785437e+35]], dtype=float32))
# (5, 'Cost: ', inf, '\nPrediction:\n', array([[-inf],
#        [-inf],
#        [-inf],
#        [-inf],
#        [-inf],
#        [-inf],
#        [-inf],
#        [-inf]], dtype=float32))
# (6, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (7, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (8, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (9, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (10, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (11, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (12, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (13, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (14, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (15, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (16, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (17, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (18, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (19, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (20, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (21, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (22, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (23, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (24, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (25, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (26, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (27, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (28, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (29, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (30, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (31, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (32, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (33, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (34, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (35, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (36, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (37, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (38, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (39, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (40, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (41, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (42, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (43, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (44, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (45, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (46, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (47, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (48, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (49, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (50, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (51, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (52, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (53, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (54, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (55, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (56, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (57, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (58, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (59, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (60, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (61, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (62, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (63, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (64, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (65, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (66, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (67, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (68, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (69, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (70, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (71, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (72, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (73, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (74, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (75, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (76, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (77, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (78, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (79, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (80, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (81, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (82, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (83, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (84, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (85, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (86, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (87, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (88, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (89, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (90, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (91, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (92, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (93, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (94, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (95, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (96, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (97, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (98, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (99, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
# (100, 'Cost: ', nan, '\nPrediction:\n', array([[ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan]], dtype=float32))
